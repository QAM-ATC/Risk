# %%
from Miscellaneous import Plot, FetchData
from Portfolio import MeanVariance
import pandas as pd
# %load_ext autoreload
# %autoreload 2

# %%
tickers = ["AAPL", "BRO", "AMZN"]
data = FetchData().test_set(ticker=tickers, startDate="2012-03-10", endDate="2014-10-10")
# Out:
# ...Data for ['AAPL', 'BRO', 'AMZN'] from 2012-03-10 to 2014-10-10 loaded successfully

# %%
pf = MeanVariance(data)
# Out:
# ...Data for USTREASURY/YIELD.3 from 2012-03-12 to 2014-10-10 loaded successfully

# %%
weight = pf.fit()

# %%
ax = Plot().weights(weight)

# %%
Plot().correlation_heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
Plot().covariance_heatmap(data.cov())
# Out:
# <AxesSubplot:>

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-118-aea68ac35cd5> in <module>
# ----> 1 Plot().efficient_frontier(optimizer=pf.portfolio, complex=False, efficentParameterRange=(0,1))
#
# ~\OneDrive - Nanyang Technological University\python files\projects\Resume Projects\Risk\Miscellaneous.py in efficient_frontier(self, optimizer, efficientParameter, efficentParameterRange, points, ax, showAssets, plot, complex, **kwargs)
#      84         ax = plotting.plot_efficient_frontier(opt=optimizer, ef_param=efficientParameter,
#      85                                                      ef_param_range=efficentParameterRange, points=points,
# ---> 86                                                      ax=ax, show_assets=showAssets, **kwargs)
#      87
#      88         if complex:
#
# ...

# %%
pf.portfolio
